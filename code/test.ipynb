# %%
from dask.dataframe import from_pandas

# %%
from pyspark.sql import SparkSession
import numpy as np
import pandas as pd

# spark = SparkSession.builder.appName('abc').getOrCreate()
data = 'https://raw.githubusercontent.com/JanathanPlanas/Machine-Learning/main/high_diamond_ranked_10min.csv'
# numpy = pd.DataFrame(np.fromfile(open("D:\Python\AICT\data\Clear\CLEAR.bin"), dtype=np.complex64))

# %%
pd.read_csv(data, dtype ="float64[pyarrow]")
# Out:
#             gameId  blueWins  blueWardsPlaced  blueWardsDestroyed
# 0     4.519158e+09       0.0             28.0                 2.0  \
# 1     4.523372e+09       0.0             12.0                 1.0
# 2     4.521475e+09       0.0             15.0                 0.0
# 3     4.524384e+09       0.0             43.0                 1.0
# 4     4.436034e+09       0.0             75.0                 4.0
# ...            ...       ...              ...                 ...
# 9874  4.527873e+09       1.0             17.0                 2.0
# 9875  4.527797e+09       1.0             54.0                 0.0
# 9876  4.527714e+09       0.0             23.0                 1.0
# 9877  4.527628e+09       0.0             14.0                 4.0
# 9878  4.523773e+09       1.0             18.0                 0.0
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters
# 0                1.0        9.0         6.0         11.0                0.0  \
# ...
