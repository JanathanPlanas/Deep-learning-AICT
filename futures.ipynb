# %%
import numpy as np
import pandas as pd


def building_data(test, column_name='unit1_pwr_60ghz_1'):
    """
    Constrói um DataFrame a partir de arquivos CSV com base em uma coluna específica
    e adiciona a coluna 'blockage_final' ao DataFrame.

    Args:
        test (pandas.DataFrame): O DataFrame de entrada contendo as colunas de dados.
        column_name (str): O nome da coluna a ser lida nos arquivos CSV.

    Returns:
        pandas.DataFrame: O DataFrame resultante com os dados concatenados e 'blockage_final' adicionada.

    Exemplo:
        >>> test_data = pd.DataFrame({'unit1_pwr_60ghz_1': ['file1.csv', 'file2.csv']})
        >>> test_data['blockage_final'] = [1, 2]
        >>> result = building_data(test_data, 'unit1_pwr_60ghz_1')
        >>> print(result.head())
           unit1_pwr_60ghz_1  blockage_final
        0                0.001               1
        1                0.002               1
        2                0.003               2
        3                0.004               2
        """
    dfs = []

    for i in range(len(test[column_name])):
        df = pd.read_csv(test[column_name][i], dtype=np.double,
                         header=None, engine='pyarrow', dtype_backend='pyarrow')
        df['blockage_1'] = test['blockage_1'][i]
        df['blockage_2'] = test['blockage_2'][i]
        df['blockage_3'] = test['blockage_3'][i]
        df['blockage_4'] = test['blockage_4'][i]
        df['blockage_5'] = test['blockage_5'][i]
        df['blockage_6'] = test['blockage_6'][i]
        df['blockage_7'] = test['blockage_7'][i]
        df['blockage_8'] = test['blockage_8'][i]
        df['blockage_9'] = test['blockage_9'][i]
        df['blockage_10'] = test['blockage_10'][i]
        dfs.append(df)

    return pd.concat(dfs, axis=0).rename(columns={0: column_name}).reset_index(drop=True)


def merge_data(test):
    """
    Mescla múltiplos DataFrames construídos usando a função 'building_data' em uma única estrutura.

    Args:
        test (pandas.DataFrame): O DataFrame contendo as colunas de dados.

    Returns:
        pandas.DataFrame: O DataFrame resultante com as colunas mescladas.

    Exemplo:
        >>> test_data = pd.DataFrame({'unit1_pwr_60ghz_1': ['file1.csv', 'file2.csv'],
        ...                           'unit1_pwr_60ghz_2': ['file3.csv', 'file4.csv']})
        >>> test_data['blockage_final'] = [1, 2]
        >>> result = merge_data(test_data)
        >>> print(result.head())
           unit1_pwr_60ghz_1  unit1_pwr_60ghz_2  blockage_final
        0                0.001                0.001               1
        1                0.002                0.002               1
        2                0.003                0.003               2
        3                0.004                0.004               2

    """
    columns = ['unit1_pwr_60ghz_1', 'unit1_pwr_60ghz_2', 'unit1_pwr_60ghz_3',
               'unit1_pwr_60ghz_4', 'unit1_pwr_60ghz_5', 'unit1_pwr_60ghz_6',
               'unit1_pwr_60ghz_7', 'unit1_pwr_60ghz_8']

    data_frames = [building_data(test, column_name) for column_name in columns]

    concat_data_frames = [pd.concat(data_frames[i:i + 2], axis=1)
                          for i in range(0, len(data_frames), 2)]

    return pd.concat(concat_data_frames, axis=1)

# Exemplo de uso:
# result = merge_data(test_data)  # Substitua 'test_data' pelos seus dados de teste

# Exemplo de uso:
# result = merge_data(test_data)  # Substitua 'test_data' pelos seus dados de teste


if __name__ == "__main__":

    test = pd.read_csv(
        r'future-5\scenario17_dev_series_val.csv')
    df_test = merge_data(test)
    df_test = merge_data(test).drop(columns=['blockage_1',
                                             'blockage_2',
                                             'blockage_3',
                                             'blockage_4',
                                             'blockage_5',
                                             'blockage_6',
                                             'blockage_7',
                                             'blockage_8',
                                             'blockage_9',
                                             'blockage_10'])

    blockage_final_column = building_data(test, 'unit1_pwr_60ghz_1')[['blockage_1',
                                                                      'blockage_2',
                                                                      'blockage_3',
                                                                      'blockage_4',
                                                                      'blockage_5',
                                                                      'blockage_6',
                                                                      'blockage_7',
                                                                      'blockage_8',
                                                                      'blockage_9',
                                                                      'blockage_10']]
    test_final = pd.concat([df_test, blockage_final_column], axis=1)
    test_final.to_parquet(r'future_clean\future-10\val.parquet')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'blockage_6'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\Python\AICT\futures.ipynb Cell 1 line 9
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=88'>89</a> if __name__ == "__main__":
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=90'>91</a>     test = pd.read_csv(
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=91'>92</a>         r'future-5\scenario17_dev_series_val.csv')
# ---> <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=92'>93</a>     df_test = merge_data(test)
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=93'>94</a>     df_test = merge_data(test).drop(columns=['blockage_1',
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=94'>95</a>                                              'blockage_2',
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=95'>96</a>                                              'blockage_3',
#    (...)
#     <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=101'>102</a>                                              'blockage_9',
#     <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=102'>103</a>                                              'blockage_10'])
#     <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=104'>105</a>     blockage_final_column = building_data(test, 'unit1_pwr_60ghz_1')[['blockage_1',
#     <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=105'>106</a>                                                                       'blockage_2',
#     <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=106'>107</a>                                                                       'blockage_3',
#    (...)
#     <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=112'>113</a>                                                                       'blockage_9',
#     <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=113'>114</a>                                                                       'blockage_10']]
#
# d:\Python\AICT\futures.ipynb Cell 1 line 7
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=48'>49</a> """
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=49'>50</a> Mescla múltiplos DataFrames construídos usando a função 'building_data' em uma única estrutura.
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=50'>51</a>
#    (...)
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=68'>69</a>
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=69'>70</a> """
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=70'>71</a> columns = ['unit1_pwr_60ghz_1', 'unit1_pwr_60ghz_2', 'unit1_pwr_60ghz_3',
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=71'>72</a>            'unit1_pwr_60ghz_4', 'unit1_pwr_60ghz_5', 'unit1_pwr_60ghz_6',
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=72'>73</a>            'unit1_pwr_60ghz_7', 'unit1_pwr_60ghz_8']
# ---> <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=74'>75</a> data_frames = [building_data(test, column_name) for column_name in columns]
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=76'>77</a> concat_data_frames = [pd.concat(data_frames[i:i + 2], axis=1)
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=77'>78</a>                       for i in range(0, len(data_frames), 2)]
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=79'>80</a> return pd.concat(concat_data_frames, axis=1)
#
# d:\Python\AICT\futures.ipynb Cell 1 line 7
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=48'>49</a> """
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=49'>50</a> Mescla múltiplos DataFrames construídos usando a função 'building_data' em uma única estrutura.
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=50'>51</a>
#    (...)
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=68'>69</a>
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=69'>70</a> """
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=70'>71</a> columns = ['unit1_pwr_60ghz_1', 'unit1_pwr_60ghz_2', 'unit1_pwr_60ghz_3',
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=71'>72</a>            'unit1_pwr_60ghz_4', 'unit1_pwr_60ghz_5', 'unit1_pwr_60ghz_6',
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=72'>73</a>            'unit1_pwr_60ghz_7', 'unit1_pwr_60ghz_8']
# ---> <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=74'>75</a> data_frames = [building_data(test, column_name) for column_name in columns]
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=76'>77</a> concat_data_frames = [pd.concat(data_frames[i:i + 2], axis=1)
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=77'>78</a>                       for i in range(0, len(data_frames), 2)]
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=79'>80</a> return pd.concat(concat_data_frames, axis=1)
#
# d:\Python\AICT\futures.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=35'>36</a> df['blockage_4'] = test['blockage_4'][i]
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=36'>37</a> df['blockage_5'] = test['blockage_5'][i]
# ---> <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=37'>38</a> df['blockage_6'] = test['blockage_6'][i]
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=38'>39</a> df['blockage_7'] = test['blockage_7'][i]
#      <a href='vscode-notebook-cell:/d%3A/Python/AICT/futures.ipynb#W0sZmlsZQ%3D%3D?line=39'>40</a> df['blockage_8'] = test['blockage_8'][i]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'blockage_6'

# %%
test = pd.read_csv(
        r'future-5\scenario17_dev_series_test.csv')
test
# Out:
#      index                          unit1_pwr_60ghz_1
# 0        1  ./unit1/mmWave_data/mmWave_power_9254.txt  \
# 1        2  ./unit1/mmWave_data/mmWave_power_6423.txt
# 2        3  ./unit1/mmWave_data/mmWave_power_6136.txt
# 3        4   ./unit1/mmWave_data/mmWave_power_488.txt
# 4        5  ./unit1/mmWave_data/mmWave_power_1864.txt
# ..     ...                                        ...
# 229    230  ./unit1/mmWave_data/mmWave_power_6909.txt
# 230    231  ./unit1/mmWave_data/mmWave_power_5222.txt
# 231    232  ./unit1/mmWave_data/mmWave_power_1867.txt
# 232    233  ./unit1/mmWave_data/mmWave_power_2368.txt
# 233    234  ./unit1/mmWave_data/mmWave_power_8078.txt
#
#                              unit1_pwr_60ghz_2
# 0    ./unit1/mmWave_data/mmWave_power_9255.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_6424.txt
# 2    ./unit1/mmWave_data/mmWave_power_6137.txt
# 3     ./unit1/mmWave_data/mmWave_power_489.txt
# 4    ./unit1/mmWave_data/mmWave_power_1865.txt
# ..                                         ...
# 229  ./unit1/mmWave_data/mmWave_power_6910.txt
# 230  ./unit1/mmWave_data/mmWave_power_5223.txt
# 231  ./unit1/mmWave_data/mmWave_power_1868.txt
# 232  ./unit1/mmWave_data/mmWave_power_2369.txt
# 233  ./unit1/mmWave_data/mmWave_power_8079.txt
#
#                              unit1_pwr_60ghz_3
# 0    ./unit1/mmWave_data/mmWave_power_9256.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_6425.txt
# 2    ./unit1/mmWave_data/mmWave_power_6138.txt
# 3     ./unit1/mmWave_data/mmWave_power_490.txt
# 4    ./unit1/mmWave_data/mmWave_power_1866.txt
# ..                                         ...
# 229  ./unit1/mmWave_data/mmWave_power_6911.txt
# 230  ./unit1/mmWave_data/mmWave_power_5224.txt
# 231  ./unit1/mmWave_data/mmWave_power_1869.txt
# 232  ./unit1/mmWave_data/mmWave_power_2370.txt
# 233  ./unit1/mmWave_data/mmWave_power_8080.txt
#
#                              unit1_pwr_60ghz_4
# 0    ./unit1/mmWave_data/mmWave_power_9257.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_6426.txt
# 2    ./unit1/mmWave_data/mmWave_power_6139.txt
# 3     ./unit1/mmWave_data/mmWave_power_491.txt
# 4    ./unit1/mmWave_data/mmWave_power_1867.txt
# ..                                         ...
# 229  ./unit1/mmWave_data/mmWave_power_6912.txt
# 230  ./unit1/mmWave_data/mmWave_power_5225.txt
# 231  ./unit1/mmWave_data/mmWave_power_1870.txt
# 232  ./unit1/mmWave_data/mmWave_power_2371.txt
# 233  ./unit1/mmWave_data/mmWave_power_8081.txt
#
#                              unit1_pwr_60ghz_5
# 0    ./unit1/mmWave_data/mmWave_power_9258.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_6427.txt
# 2    ./unit1/mmWave_data/mmWave_power_6140.txt
# 3     ./unit1/mmWave_data/mmWave_power_492.txt
# 4    ./unit1/mmWave_data/mmWave_power_1868.txt
# ..                                         ...
# 229  ./unit1/mmWave_data/mmWave_power_6913.txt
# 230  ./unit1/mmWave_data/mmWave_power_5226.txt
# 231  ./unit1/mmWave_data/mmWave_power_1871.txt
# 232  ./unit1/mmWave_data/mmWave_power_2372.txt
# 233  ./unit1/mmWave_data/mmWave_power_8082.txt
#
#                              unit1_pwr_60ghz_6
# 0    ./unit1/mmWave_data/mmWave_power_9259.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_6428.txt
# 2    ./unit1/mmWave_data/mmWave_power_6141.txt
# 3     ./unit1/mmWave_data/mmWave_power_493.txt
# 4    ./unit1/mmWave_data/mmWave_power_1869.txt
# ..                                         ...
# 229  ./unit1/mmWave_data/mmWave_power_6914.txt
# 230  ./unit1/mmWave_data/mmWave_power_5227.txt
# 231  ./unit1/mmWave_data/mmWave_power_1872.txt
# 232  ./unit1/mmWave_data/mmWave_power_2373.txt
# 233  ./unit1/mmWave_data/mmWave_power_8083.txt
#
#                              unit1_pwr_60ghz_7
# 0    ./unit1/mmWave_data/mmWave_power_9260.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_6429.txt
# 2    ./unit1/mmWave_data/mmWave_power_6142.txt
# 3     ./unit1/mmWave_data/mmWave_power_494.txt
# 4    ./unit1/mmWave_data/mmWave_power_1870.txt
# ..                                         ...
# 229  ./unit1/mmWave_data/mmWave_power_6915.txt
# 230  ./unit1/mmWave_data/mmWave_power_5228.txt
# 231  ./unit1/mmWave_data/mmWave_power_1873.txt
# 232  ./unit1/mmWave_data/mmWave_power_2374.txt
# 233  ./unit1/mmWave_data/mmWave_power_8084.txt
#
#                              unit1_pwr_60ghz_8  blockage_1  blockage_2
# 0    ./unit1/mmWave_data/mmWave_power_9261.txt           0           0  \
# 1    ./unit1/mmWave_data/mmWave_power_6430.txt           1           1
# 2    ./unit1/mmWave_data/mmWave_power_6143.txt           0           0
# 3     ./unit1/mmWave_data/mmWave_power_495.txt           0           1
# 4    ./unit1/mmWave_data/mmWave_power_1871.txt           0           0
# ..                                         ...         ...         ...
# 229  ./unit1/mmWave_data/mmWave_power_6916.txt           0           0
# 230  ./unit1/mmWave_data/mmWave_power_5229.txt           0           0
# 231  ./unit1/mmWave_data/mmWave_power_1874.txt           0           0
# 232  ./unit1/mmWave_data/mmWave_power_2375.txt           0           0
# 233  ./unit1/mmWave_data/mmWave_power_8085.txt           0           1
#
#      blockage_3  blockage_4  blockage_5
# 0             0           0           0
# 1             1           1           0
# 2             0           0           0
# 3             1           1           1
# 4             0           0           0
# ..          ...         ...         ...
# 229           0           0           0
# 230           0           0           0
# 231           1           1           1
# 232           0           0           0
# 233           1           1           1
#
# [234 rows x 14 columns]

# %%
test_final
# Out:
#       unit1_pwr_60ghz_1  unit1_pwr_60ghz_2  unit1_pwr_60ghz_3
# 0              0.000103           0.000103           0.000101  \
# 1              0.000220           0.000372           0.000266
# 2              0.000403           0.000407           0.000420
# 3              0.000383           0.000392           0.000401
# 4              0.000264           0.000259           0.000213
# ...                 ...                ...                ...
# 3195           0.000213           0.000248           0.000342
# 3196           0.000362           0.000442           0.000483
# 3197           0.000281           0.000287           0.000364
# 3198           0.000136           0.000183           0.000215
# 3199           0.000065           0.000093           0.000069
#
#       unit1_pwr_60ghz_4  unit1_pwr_60ghz_5  unit1_pwr_60ghz_6
# 0              0.000099           0.000097           0.000095  \
# 1              0.000275           0.000324           0.000230
# 2              0.000419           0.000411           0.000410
# 3              0.000371           0.000402           0.000389
# 4              0.000197           0.000264           0.000182
# ...                 ...                ...                ...
# 3195           0.000276           0.000241           0.000171
# 3196           0.000415           0.000398           0.000321
# 3197           0.000229           0.000267           0.000289
# 3198           0.000109           0.000087           0.000103
# 3199           0.000059           0.000044           0.000034
#
#       unit1_pwr_60ghz_7  unit1_pwr_60ghz_8  blockage_final
# 0              0.000093           0.000096               0
# 1              0.000418           0.000399               0
# 2              0.000402           0.000393               0
# 3              0.000390           0.000374               0
# 4              0.000264           0.000254               0
# ...                 ...                ...             ...
# 3195           0.000312           0.000248               0
# 3196           0.000346           0.000375               0
# 3197           0.000139           0.000247               0
# 3198           0.000063           0.000065               0
# 3199           0.000030           0.000031               0
#
# [3200 rows x 9 columns]

# %%
pd.read_parquet(r'future_clean\future-1\val.parquet')
# Out:
#      index                          unit1_pwr_60ghz_1
# 0        1  ./unit1/mmWave_data/mmWave_power_5849.txt  \
# 1        2  ./unit1/mmWave_data/mmWave_power_2557.txt
# 2        3  ./unit1/mmWave_data/mmWave_power_5583.txt
# 3        4  ./unit1/mmWave_data/mmWave_power_7781.txt
# 4        5  ./unit1/mmWave_data/mmWave_power_3591.txt
# ..     ...                                        ...
# 157    158  ./unit1/mmWave_data/mmWave_power_6631.txt
# 158    159  ./unit1/mmWave_data/mmWave_power_1802.txt
# 159    160  ./unit1/mmWave_data/mmWave_power_1671.txt
# 160    161  ./unit1/mmWave_data/mmWave_power_9591.txt
# 161    162  ./unit1/mmWave_data/mmWave_power_7159.txt
#
#                              unit1_pwr_60ghz_2
# 0    ./unit1/mmWave_data/mmWave_power_5850.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_2558.txt
# 2    ./unit1/mmWave_data/mmWave_power_5584.txt
# 3    ./unit1/mmWave_data/mmWave_power_7782.txt
# 4    ./unit1/mmWave_data/mmWave_power_3592.txt
# ..                                         ...
# 157  ./unit1/mmWave_data/mmWave_power_6632.txt
# 158  ./unit1/mmWave_data/mmWave_power_1803.txt
# 159  ./unit1/mmWave_data/mmWave_power_1672.txt
# 160  ./unit1/mmWave_data/mmWave_power_9592.txt
# 161  ./unit1/mmWave_data/mmWave_power_7160.txt
#
#                              unit1_pwr_60ghz_3
# 0    ./unit1/mmWave_data/mmWave_power_5851.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_2559.txt
# 2    ./unit1/mmWave_data/mmWave_power_5585.txt
# 3    ./unit1/mmWave_data/mmWave_power_7783.txt
# 4    ./unit1/mmWave_data/mmWave_power_3593.txt
# ..                                         ...
# 157  ./unit1/mmWave_data/mmWave_power_6633.txt
# 158  ./unit1/mmWave_data/mmWave_power_1804.txt
# 159  ./unit1/mmWave_data/mmWave_power_1673.txt
# 160  ./unit1/mmWave_data/mmWave_power_9593.txt
# 161  ./unit1/mmWave_data/mmWave_power_7161.txt
#
#                              unit1_pwr_60ghz_4
# 0    ./unit1/mmWave_data/mmWave_power_5852.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_2560.txt
# 2    ./unit1/mmWave_data/mmWave_power_5586.txt
# 3    ./unit1/mmWave_data/mmWave_power_7784.txt
# 4    ./unit1/mmWave_data/mmWave_power_3594.txt
# ..                                         ...
# 157  ./unit1/mmWave_data/mmWave_power_6634.txt
# 158  ./unit1/mmWave_data/mmWave_power_1805.txt
# 159  ./unit1/mmWave_data/mmWave_power_1674.txt
# 160  ./unit1/mmWave_data/mmWave_power_9594.txt
# 161  ./unit1/mmWave_data/mmWave_power_7162.txt
#
#                              unit1_pwr_60ghz_5
# 0    ./unit1/mmWave_data/mmWave_power_5853.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_2561.txt
# 2    ./unit1/mmWave_data/mmWave_power_5587.txt
# 3    ./unit1/mmWave_data/mmWave_power_7785.txt
# 4    ./unit1/mmWave_data/mmWave_power_3595.txt
# ..                                         ...
# 157  ./unit1/mmWave_data/mmWave_power_6635.txt
# 158  ./unit1/mmWave_data/mmWave_power_1806.txt
# 159  ./unit1/mmWave_data/mmWave_power_1675.txt
# 160  ./unit1/mmWave_data/mmWave_power_9595.txt
# 161  ./unit1/mmWave_data/mmWave_power_7163.txt
#
#                              unit1_pwr_60ghz_6
# 0    ./unit1/mmWave_data/mmWave_power_5854.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_2562.txt
# 2    ./unit1/mmWave_data/mmWave_power_5588.txt
# 3    ./unit1/mmWave_data/mmWave_power_7786.txt
# 4    ./unit1/mmWave_data/mmWave_power_3596.txt
# ..                                         ...
# 157  ./unit1/mmWave_data/mmWave_power_6636.txt
# 158  ./unit1/mmWave_data/mmWave_power_1807.txt
# 159  ./unit1/mmWave_data/mmWave_power_1676.txt
# 160  ./unit1/mmWave_data/mmWave_power_9596.txt
# 161  ./unit1/mmWave_data/mmWave_power_7164.txt
#
#                              unit1_pwr_60ghz_7
# 0    ./unit1/mmWave_data/mmWave_power_5855.txt  \
# 1    ./unit1/mmWave_data/mmWave_power_2563.txt
# 2    ./unit1/mmWave_data/mmWave_power_5589.txt
# 3    ./unit1/mmWave_data/mmWave_power_7787.txt
# 4    ./unit1/mmWave_data/mmWave_power_3597.txt
# ..                                         ...
# 157  ./unit1/mmWave_data/mmWave_power_6637.txt
# 158  ./unit1/mmWave_data/mmWave_power_1808.txt
# 159  ./unit1/mmWave_data/mmWave_power_1677.txt
# 160  ./unit1/mmWave_data/mmWave_power_9597.txt
# 161  ./unit1/mmWave_data/mmWave_power_7165.txt
#
#                              unit1_pwr_60ghz_8  blockage_final
# 0    ./unit1/mmWave_data/mmWave_power_5856.txt               1
# 1    ./unit1/mmWave_data/mmWave_power_2564.txt               1
# 2    ./unit1/mmWave_data/mmWave_power_5590.txt               0
# 3    ./unit1/mmWave_data/mmWave_power_7788.txt               1
# 4    ./unit1/mmWave_data/mmWave_power_3598.txt               0
# ..                                         ...             ...
# 157  ./unit1/mmWave_data/mmWave_power_6638.txt               0
# 158  ./unit1/mmWave_data/mmWave_power_1809.txt               0
# 159  ./unit1/mmWave_data/mmWave_power_1678.txt               1
# 160  ./unit1/mmWave_data/mmWave_power_9598.txt               0
# 161  ./unit1/mmWave_data/mmWave_power_7166.txt               1
#
# [162 rows x 10 columns]
